# %%
print("hello")

# %%
# !pip install arxiv
# Out:
# Collecting arxiv
#   Downloading arxiv-2.3.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting feedparser~=6.0.10 (from arxiv)
#   Downloading feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: requests~=2.32.0 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from arxiv) (2.32.5)
# Collecting sgmllib3k (from feedparser~=6.0.10->arxiv)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from requests~=2.32.0->arxiv) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from requests~=2.32.0->arxiv) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from requests~=2.32.0->arxiv) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from requests~=2.32.0->arxiv) (2025.10.5)
# Downloading arxiv-2.3.1-py3-none-any.whl (11 kB)
# Downloading feedparser-6.0.12-py3-none-any.whl (81 kB)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (pyproject.toml): started
#   Building wheel for sgmllib3k (pyproject.toml): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6105 sha256=1c8ecf10e4749410ff8e0fb27e7bb9ad0a3c9774d810e854362fd18b0e5eaf6f
#   Stored in directory: c:\users\dhanaranjitha\appdata\local\pip\cache\wheels\03\f5\1a\23761066dac1d0e8e683e5fdb27e12de53209d05a4a37e6246
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser, arxiv
#
#    ------------- -------------------------- 1/3 [feedparser]
#    ------------- -------------------------- 1/3 [feedparser]
#    ------------- -------------------------- 1/3 [feedparser]
#    ------------- -------------------------- 1/3 [feedparser]
#    ------------- -------------------------- 1/3 [feedparser]
#    ------------- -------------------------- 1/3 [feedparser]
#    ------------- -------------------------- 1/3 [feedparser]
#    ---------------------------------------- 3/3 [arxiv]
#
# Successfully installed arxiv-2.3.1 feedparser-6.0.12 sgmllib3k-1.0.0

# %%
from langchain_community.tools import WikipediaQueryRun
from langchain_community.utilities import WikipediaAPIWrapper

# %%
# !pip install wikipedia
# Out:
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from wikipedia) (4.14.2)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from wikipedia) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2025.10.5)
# Requirement already satisfied: soupsieve>1.2 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from beautifulsoup4->wikipedia) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from beautifulsoup4->wikipedia) (4.15.0)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (pyproject.toml): started
#   Building wheel for wikipedia (pyproject.toml): finished with status 'done'
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11785 sha256=adad0648b0150ed92a57c5bab0558152f874e54738a3275ca320bab01fcb888d
#   Stored in directory: c:\users\dhanaranjitha\appdata\local\pip\cache\wheels\63\47\7c\a9688349aa74d228ce0a9023229c6c0ac52ca2a40fe87679b8
# Successfully built wikipedia
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0

# %%
api_wrapper=WikipediaAPIWrapper(top_k_results=1,doc_content_chars_max=200)
tool=WikipediaQueryRun(api_wrapper=api_wrapper)

# %%
tool.name
# Out:
# 'wikipedia'

# %%
# !pip install langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in c:\ranjithaprojects\langchain\venv\lib\site-packages (1.0.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from langchain-text-splitters) (1.0.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.4.38)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: anyio in c:\ranjithaprojects\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (4.11.0)
# Requirement already satisfied: certifi in c:\ranjithaprojects\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\ranjithaprojects\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in c:\ranjithaprojects\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\ranjithaprojects\langchain\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.3.1)

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import SentenceTransformerEmbeddings
from langchain.text_splitter import RecursiveCharacterTextSplitter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 4
#       2 from langchain_community.vectorstores import FAISS
#       3 from langchain_community.embeddings import SentenceTransformerEmbeddings
# ----> 4 from langchain.text_splitter import RecursiveCharacterTextSplitter
#
# ModuleNotFoundError: No module named 'langchain.text_splitter'

# %%
loader-web
